# %%
import shelve
import os
import time

# %%
pwd
# Out:
# 'D:\\Batch_10_am\\Core Python\\file handling\\File Handling\\SUPERMARKET_PROJECT'

# %%
# !type dictionary.py
# Out:
# stationary={
#             'pen':{'brand':{'link':{'price':[5,10],'stock':[200,100]},
#                             'fine':{'price':[5,10],'stock':[250,150]}
#                            }
#                   },
#             'register':{'brand':{'classmate':{'price':[50,80],'stock':[100,50]},
#                             'icon':{'price':[50,60],'stock':[200,80]}
#                            }
#                       },
#             'books':{'class VI':{'price':500,'stock':20},
#                      'class VII':{'price':600,'stock':20},
#                      'class VIII':{'price':700,'stock':20},
#                      'class IX':{'price':800,'stock':20},
#                      'class X':{'price':900,'stock':20},
#                     }
# }
#
# electronics={
#             'mobile':{'brand':{'one plus':{'model':['7 pro','8 pro','7'],'price':[40000,46000,35000],'stock':[20,20,10]},
# ...

# %%
stationary={
            'pen':{'brand':{'link':{'price':[5,10],'stock':[200,100]},
                            'fine':{'price':[5,10],'stock':[250,150]}
                           }
                  },
            'register':{'brand':{'classmate':{'price':[50,80],'stock':[100,50]},
                            'icon':{'price':[50,60],'stock':[200,80]}
                           }
                      },
            'books':{'class VI':{'price':500,'stock':20},
                     'class VII':{'price':600,'stock':20},
                     'class VIII':{'price':700,'stock':20},
                     'class IX':{'price':800,'stock':20},
                     'class X':{'price':900,'stock':20},
                    }
}

electronics={
            'mobile':{'brand':{'one plus':{'model':['7 pro','8 pro','7'],'price':[40000,46000,35000],'stock':[20,20,10]},
                              'iphone':{'model':['6','10','11'],'price':[20000,56000,100000],'stock':[20,20,10]},
                              'MI':{'model':['10 pro','8 pro','8A','7 pro','6A'],'price':[40000,15000,9000,10000,8000],'stock':[20,50,50,30,100]}
                             }
                  },
            'laptop':{'brand':{'hp':{'model':['HP Pavilion Gaming 15','HP Omen 15','HP Spectre x360 (2019)'],'price':[55000,95000,150000],'stock':[5,5,5]},
                              'samsung':{'model':['Samsung ChromeBook XE50','Samsung ChromeBook 3 XE501C13-K01US','Samsung Spin 7 NP730QAA'],'price':[25000,46000,90000],'stock':[20,20,10]},
                              'dell':{'model':['Dell Inspiron Core','Dell Inspiron Touchscreen 15 5548 Notebook','Dell Vostro 3458'],'price':[25000,75000,29000],'stock':[15,10,20]}
                             }
                  }
}



cosmatic={
            'bodylotion':{'brand':{'joy':{'price':[50,100],'stock':[100,50]},
                                   'vaseline':{'price':[120,200],'stock':[120,100]}
                           }
                  },
            'soap':{'brand':{'lifeboy':{'price':[10,20],'stock':[100,50]},
                            'dettol':{'price':[20,40],'stock':[200,80]},
                            'godrej no.1 ':{'price':[15,25],'stock':[200,80]},
                           }
                },
            'cream':{'brand':{'boroplus':{'price':[20,40],'stock':[100,50]},
                            'fair Handsome':{'price':[20,40],'stock':[200,80]},
                            'meglow':{'price':[50,100],'stock':[200,80]},
                           }
                   },
            'perfume':{'brand':{'denver':{'price':[100,200],'stock':[100,50]},
                            'park avenue':{'price':[120,180],'stock':[200,80]},
                            'fogg':{'price':[150,195],'stock':[200,80]},
                           }
                   }
}



chocolate={
            'dairymilk':{'price':[20,40,60,80,100],'stock':[100,90,80,70,60]},
            'munch':{'price':[5,10,20,40,60],'stock':[100,90,80,70,60]},
            'kit-kat':{'price':[5,10,20,40,60],'stock':[100,90,80,70,60]},
            'five star':{'price':[5,10,20,40],'stock':[100,80,70,60]},
            'perk':{'price':[5,10,20,40],'stock':[100,90,80,70]}
    
}

# %%
pwd
# Out:
# 'D:\\Batch_10_am\\Core Python\\file handling\\File Handling\\SUPERMARKET_PROJECT'

# %%
os.mkdir("Supermarket/")

# %%
db = shelve.open("Supermarket/data.txt",writeback = True)

# %%
db['stationary'] = stationary
db['electronics'] = electronics
db['cosmatic'] = cosmatic
db['chocolate'] = chocolate

# %%
db.close()

# %%
import time
import shelve
l = ["Stationary\tProduct\tBrand\tQt\tPrice/qt\tTotal"]

def main():
    s = "1. Stationary\n2. Electronics\n3. Cosmatic\n4. Chocolate"
    print(s)
    ch = int(input("Enter the choice from above: "))
    if ch == 1:
        stationary()
    elif ch == 2:
        electronics()
    elif ch == 3:
        cosmatic()
    elif ch == 4:
        chocolate()
    else:
        exit()

# %%
 def stationary():
        global l
        db = shelve.open("Supermarket/data.txt",writeback = True)
        data = db["stationary"]
        print("Available items in stationary")
        c = 1
        for i in data:
            print(c,'.',i.capitalize(),sep = '')
            c+=1
        print(c,".Main",sep = '')
        ch = int(input("Enter the choice from above: "))
        if ch == 1:
            c = 1
            for i in data['pen']['brand']:
                print(c,'.',i.capitalize(),sep = '')
                c+=1
            ch == int(input("Enter the brand name from above: "))
            if ch == 1:
                b= data['pen']['brand']['link']
                print("Available price", b['price'])
                price = int(input("Enter the price from above: "))
                if price in b['price']:
                    ind = b['price'].index(price)
                    qt = int(input("enter the quantity: "))
                    b['stock'][ind]-=qt
                    print(b['stock'])
                    print(f"you purchased {qt} quantity of pen")
                    l.append(f"Stationary\tPen\tLink\t{qt}\t{price}\t{qt*price}")
                    db.close()
                    stationary()
            else:
                b= data['pen']['brand']['fine']
                print("Available price", b['price'])
                price = int(input("Enter the price from above: "))
                if price in b['price']:
                    ind = b['price'].index(price)
                    qt = int(input("enter the quantity: "))
                    b['stock'][ind]-=qt
                    print(b['stock'])
                    print(f"you purchased {qt} quantity of pen")
                    l.append(f"Stationary\tPen\tFine\t{qt}\t{price}\t{qt*price}")
                    db.close()
                    stationary()
        elif ch == 2:
            c = 1
            for i in data['register']['brand']:
                print(c,'.',i.capitalize(),sep = '')
                c+=1
            ch == int(input("Enter the brand name from above: "))
            if ch == 1:
                b= data['register']['brand']['classmate']
                print("Available price", b['price'])
                price = int(input("Enter the price from above: "))
                if price in b['price']:
                    ind = b['price'].index(price)
                    qt = int(input("enter the quantity: "))
                    b['stock'][ind]-=qt
                    print(b['stock'])
                    print(f"you purchased {qt} quantity of pen")
                    l.append(f"Stationary\tRegister\tClassmate\t{qt}\t{price}\t{qt*price}")
                    db.close()
                    stationary()
                
                
            else:
                b= data['register']['brand']['icon']
                print("Available price", b['price'])
                price = int(input("Enter the price from above: "))
                if price in b['price']:
                    ind = b['price'].index(price)
                    qt = int(input("enter the quantity: "))
                    b['stock'][ind]-=qt
                    print(b['stock'])
                    print(f"you purchased {qt} quantity of pen")
                    l.append(f"Stationary\tRegister\ticon\t{qt}\t{price}\t{qt*price}")
                    db.close()
                    stationary()
                    
                
       
        elif ch == 3:
            c = 1
            for i in data['books']:
                print(c,'.',i.capitalize(),sep = '')
                c+=1
            ch == int(input("Enter the class name from above: "))
            if ch==1:
                b= data['books']['class VI']
                print("Available price", b['price'])
                qt = int(input("enter the quantity: "))
                b['stock']-=qt
                price = b['price']
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                l.append(f"Stationary\tBooks\tNA\t{qt}\t{price}\t{qt*price}")
                db.close()
                stationary()
            elif ch == 2:
                b= data['books']['class VII']
                print("Available price", b['price'])
                qt = int(input("enter the quantity: "))
                b['stock']-=qt
                price = b['price']
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                l.append(f"Stationary\tBooks\tNA\t{qt}\t{price}\t{qt*price}")
                db.close()
                stationary()
            elif ch ==3:
                b= data['books']['class VIII']
                print("Available price", b['price'])
                qt = int(input("enter the quantity: "))
                b['stock']-=qt
                price = b['price']
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                l.append(f"Stationary\tBooks\tNA\t{qt}\t{price}\t{qt*price}")
                db.close()
                stationary()
            elif ch==4:
                b= data['books']['class IX']
                print("Available price", b['price'])
                qt = int(input("enter the quantity: "))
                b['stock']-=qt
                price = b['price']
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                l.append(f"Stationary\tBooks\tNA\t{qt}\t{price}\t{qt*price}")
                db.close()
                stationary()
            elif ch == 5:
                b= data['books']['class X']
                print("Available price", b['price'])
                qt = int(input("enter the quantity: "))
                b['stock']-=qt
                price = b['price']
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                l.append(f"Stationary\tBooks\tNA\t{qt}\t{price}\t{qt*price}")
                db.close()
                stationary()
            else:
                print("invalid option...")
                stationary()
        else:
            print("invalid option...")
            main()

# %%
def electronics():
    db = shelve.open("Supermarket/data.txt",writeback = True)
    data = db["electronics"]
    print("Available items in electronics")
    c = 1
    for i in data:
        print(c,'.',i.capitalize(),sep = '')
        c+=1
    print(c,".Main",sep = '')
    ch = int(input("Enter the electronic item you want from above: "))
    if ch == 1:
        c = 1
        for i in data['mobile']['brand']:
            print(c,'.',i.capitalize(),sep = '')
            c+=1
        ch == int(input("Enter the brand name from above: "))
        if ch == 1:
            b = data['mobile']['brand']['one plus']
            print(b['model'])
            model_= input("Enter the model name: ")
            if model_ in b['model']:
                ind = b['model'].index(model_)
                print(b['price'][ind])
                qt = int(input("Enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of oneplus phone")
                db.close()
                electronics()
        elif ch == 2:
            b = data['mobile']['brand']['iphone']
            print(b['model'])
            model_= input("Enter the model name: ")
            if model_ in b['model']:
                ind = b['model'].index(model_)
                print(b['price'][ind])
                qt = int(input("Enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of Iphone phone")
                db.close()
                electronics()
            
        elif ch == 3:
            b = data['mobile']['brand']['MI']
            print(b['model'])
            model_= input("Enter the model name: ")
            if model_ in b['model']:
                ind = b['model'].index(model_)
                print(b['price'][ind])
                qt = int(input("Enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of MI phone")
                db.close()
                electronics()
                
        else:
            print("\nInvalid Option...")
            electronics()
    
    elif ch == 2:
        c = 1
        for i in data['laptop']['brand']:
            print(c,'.',i.capitalize(),sep = '')
            c+=1
        print(c,".Main",sep = '')
        ch = int(input("Enter the electronic item you want from above: "))
        if ch == 1:
            b = data['laptop']['brand']['hp']
            print(b['model'])
            model_= input("Enter the model name: ")
            if model_ in b['model']:
                ind = b['model'].index(model_)
                print(b['price'][ind])
                qt = int(input("Enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of laptop")
                db.close()
                electronics()
                
        elif ch == 2:
            b = data['laptop']['brand']['samsung']
            print(b['model'])
            model_= input("Enter the model name: ")
            if model_ in b['model']:
                ind = b['model'].index(model_)
                print(b['price'][ind])
                qt = int(input("Enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of laptop")
                db.close()
                electronics()
                
        elif ch == 3:
            b = data['laptop']['brand']['dell']
            print(b['model'])
            model_= input("Enter the model name: ")
            if model_ in b['model']:
                ind = b['model'].index(model_)
                print(b['price'][ind])
                qt = int(input("Enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of laptop")
                db.close()
                electronics()
                
        else:
            print("\ninvalid option....")
            electronics()
                  
                  
    else:
                  print("\nInvalid option...")
                  main()

# %%
def cosmatic():
    db = shelve.open("Supermarket/data.txt",writeback = True)
    data = db["cosmatic"]
    print("Available items in cosmatic")
    c = 1
    for i in data:
        print(c,'.',i.capitalize(),sep = '')
        c+=1
    print(c,".Main",sep = '')
    ch = int(input("Enter the choice from above: "))
    if ch == 1:
        c = 1
        for i in data['bodylotion']['brand']:
            print(c,'.',i.capitalize(),sep = '')
            c+=1
        ch == int(input("Enter the brand name from above: "))
        if ch == 1:
            b= data['bodylotion']['brand']['joy']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                db.close()
                cosmatic()
            else:
                b= data['bodylotion']['brand']['vaseline']
                print("Available price", b['price'])
                price = int(input("Enter the price from above: "))
                if price in b['price']:
                    ind = b['price'].index(price)
                    qt = int(input("enter the quantity: "))
                    b['stock'][ind]-=qt
                    print(b['stock'])
                    print(f"you purchased {qt} quantity of pen")
                    db.close()
                    cosmatic()
    elif ch == 2:
        c = 1
        for i in data['soap']['brand']:
            print(c,'.',i.capitalize(),sep = '')
            c+=1
        ch == int(input("Enter the brand name from above: "))
        if ch == 1:
            b= data['soap']['brand']['lifeboy']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                db.close()
                cosmatic()
        elif ch == 2:
            b= data['soap']['brand']['dettol']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                db.close()
                cosmatic()
        elif ch == 3:
            b= data['soap']['brand']['godrej no. 1']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                db.close()
                cosmatic()
        else:
            print("invalid option")
            cosmatic()
    elif ch == 3 :
        c = 1
        for i in data['cream']['brand']:
            print(c,'.',i.capitalize(),sep = '')
            c+=1
        ch == int(input("Enter the brand name from above: "))
        if ch == 1:
            b= data['cream']['brand']['boroplus']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                db.close()
                cosmatic()
        elif ch == 2:
            b= data['cream']['brand']['fair Handsome']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                db.close()
                cosmatic()
                    
        elif ch == 3:
            b= data['cream']['brand']['meglow']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                db.close()
                cosmatic()
            
        else:
            print("\nInvalid Option")
            cosmatic()
    elif ch ==4:
        c = 1
        for i in data['perfume']['brand']:
            print(c,'.',i.capitalize(),sep = '')
            c+=1
        ch == int(input("Enter the brand name from above: "))
        if ch == 1:
            b= data['cream']['brand']['denver']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                db.close()
                cosmatic()
                
        elif ch == 2:
            b= data['cream']['brand']['park avenue']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                db.close()
                cosmatic()
            
        elif ch == 3:
            b= data['cream']['brand']['fogg']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of pen")
                db.close()
                cosmatic()
        else:
            ("\nInvalid Option...")
            cosmatic()
            
    else:
        ("\nInvalid Option")
        main()

# %%
def chocolate():
        db = shelve.open("Supermarket/data.txt",writeback = True)
        data = db["chocolate"]
        print("Available brands in chocolate")
        c = 1
        for i in data:
            print(c,'.',i.capitalize(),sep = '')
            c+=1
        print(c,".Main",sep = '')
        ch = int(input("Enter the chocolate name from above: "))
        if ch == 1:
            b= data['dairymilk']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of dairymilk chocolate")
                db.close()
                chocolate()
        elif ch == 2:
            b= data['munch']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of munch chocolate")
                db.close()
                chocolate()
                
        elif ch == 3:
            b= data['kit-kat']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of kit kat chocolate")
                db.close()
                chocolate()
                
        elif ch == 4:
            b= data['five star']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of five star chocolate")
                db.close()
                chocolate()
                
        elif ch == 5:
            b= data['perk']
            print("Available price", b['price'])
            price = int(input("Enter the price from above: "))
            if price in b['price']:
                ind = b['price'].index(price)
                qt = int(input("enter the quantity: "))
                b['stock'][ind]-=qt
                print(b['stock'])
                print(f"you purchased {qt} quantity of perk chocolate")
                db.close()
                chocolate()
                
        else:
            print("\Invalid Option")
            main()

# %%
def exit():
    global l
    
    for i in l:
        for j in i.split('\t'):
            print(f"{j :>10}",end='\t')

        print()
        print('_'*100)

    price = 0
    for i in l[1:]:

        price = price + int(i.split('\t')[-1])
    print()   
    print('Grand Total:-'.ljust(85,' '),price)
    l = ["Stationary\tProduct\tBrand\tQt\tPrice/qt\tTotal"]
    print('Thanks for using our application')
    for i in '..........Exiting..........':
        print(i,end='')
        time.sleep(0.09)

# %%
main()
# Out:
# 1. Stationary
# 2. Electronics
# 3. Cosmatic
# 4. Chocolate
# Enter the choice from above: 1
# Available items in stationary
# 1.Pen
# 2.Register
# 3.Books
# 4.Main
# Enter the choice from above: 2
# 1.Classmate
# 2.Icon
# Enter the brand name from above: 1
# Available price [50, 60]
# Enter the price from above: 50
# enter the quantity: 1
# [198, 80]
# you purchased 1 quantity of pen
# Available items in stationary
# 1.Pen
# 2.Register
# 3.Books
# 4.Main
# Enter the choice from above: 3
# 1.Class vi
# 2.Class vii
# 3.Class viii
# 4.Class ix
# 5.Class x
# Enter the class name from above: 1
# Available price 700
# enter the quantity: 1
# 18
# you purchased 1 quantity of pen
# Available items in stationary
# 1.Pen
# 2.Register
# 3.Books
# 4.Main
# Enter the choice from above: 3
# 1.Class vi
# 2.Class vii
# 3.Class viii
# 4.Class ix
# 5.Class x
# Enter the class name from above: 4
# Available price 700
# enter the quantity: 1
# 17
# you purchased 1 quantity of pen
# ...
